# %% [markdown]
# <div style="
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Arial, sans-serif;
#   line-height: 1.55;
#   color: var(--vscode-editor-foreground);
# ">
#
# <h2 style="margin-bottom:6px;">Learning Day 9 — Ensemble Methods: Bagging &amp; Stacking</h2>
# <p style="margin-top:0; font-size:15px;">
# <strong>Notebook 01:</strong> Source Audit, Coverage Matrix, and Dataset Selection
# </p>
#
# <div style="border-left:4px solid #38bdf8; padding:10px 14px; margin:12px 0; background:var(--vscode-editorWidget-background); border-radius:6px;">
# <strong>Main rule for this project:</strong><br>
# The uploaded lecture materials define the full Day 9 scope. The MVD assignment is only the minimum proof checklist, not the boundary of the project.
# </div>
#
# <p>
# This notebook does not train models yet. Its job is to lock the project scope before implementation starts, so no topic from the uploaded materials is accidentally missed.
# </p>
#
# </div>

# %% [markdown]
# <div style="
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Arial, sans-serif;
#   line-height: 1.55;
#   color: var(--vscode-editor-foreground);
# ">
#
# <h3 style="margin-bottom:6px;">What we are doing in this notebook</h3>
#
# <table style="border-collapse:collapse; width:100%; font-size:14px;">
# <thead>
# <tr>
# <th style="text-align:left; border-bottom:1px solid #888; padding:6px;">Step</th>
# <th style="text-align:left; border-bottom:1px solid #888; padding:6px;">Purpose</th>
# </tr>
# </thead>
# <tbody>
# <tr><td style="padding:6px;">1. Source inventory</td><td style="padding:6px;">List every uploaded Day 9 file and classify its role.</td></tr>
# <tr><td style="padding:6px;">2. Coverage matrix</td><td style="padding:6px;">Map every topic to theory, practical notebooks, business interpretation, and final proof.</td></tr>
# <tr><td style="padding:6px;">3. Dataset selection</td><td style="padding:6px;">Choose a dataset that fits the course tasks and Ruturaj's Data Analyst / BI profile.</td></tr>
# <tr><td style="padding:6px;">4. Notebook architecture</td><td style="padding:6px;">Define the full Day 9 notebook plan before coding.</td></tr>
# </tbody>
# </table>
#
# <div style="border-left:4px solid #f59e0b; padding:10px 14px; margin:12px 0; background:var(--vscode-editorWidget-background); border-radius:6px;">
# <strong>Important points for understanding and clarity</strong><br>
# Detailed theory is explained in chat first. The notebooks stay practical and include only short theory reminders, important points, code, results, and business interpretation.
# </div>
#
# </div>

# %% [markdown]
# <div style="
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Arial, sans-serif;
#   line-height: 1.55;
#   color: var(--vscode-editor-foreground);
# ">
#
# <h3 style="margin-bottom:6px;">Source inventory and coverage-control tables</h3>
#
# <p>
# The next cell creates five planning tables as reusable CSV files in the relative folder <code>reports/</code>.
# These tables become the control system for the full Day 9 project.
# </p>
#
# <div style="border-left:4px solid #38bdf8; padding:10px 14px; margin:12px 0; background:var(--vscode-editorWidget-background); border-radius:6px;">
# <strong>Important points for understanding</strong><br>
# <ul style="margin:6px 0 0 18px; padding:0;">
# <li>The source inventory prevents missed lecture files.</li>
# <li>The coverage matrix prevents missed theory or implementation topics.</li>
# <li>The MVD checklist proves assignment completion, but it is not the full scope.</li>
# <li>The dataset decision table makes the dataset choice transparent.</li>
# </ul>
# </div>
#
# </div>

# %%
# Day 9 Notebook 01 setup
# This notebook creates project planning tables that will control the full Day 9 workflow.

from pathlib import Path
import pandas as pd

# Relative folders only — no personal/local machine paths.
reports_dir = Path("reports")
reports_dir.mkdir(parents=True, exist_ok=True)

source_inventory_data = [{'Source_File': 'MVD_ML_Tasks_English_educx_CI-merged(2).pdf', 'Source_Group': 'MVD assignment', 'Role': 'Minimum proof checklist', 'Key_Topics': 'Decision Tree vs Random Forest, feature importance, n_estimators curve, StackingClassifier, CV comparison, meta-model swap, OOF stacking, blending, three-layer stacking', 'Coverage_Action': 'Track every item in Notebook 07 proof checklist and implement across Notebooks 03–06', 'Status': 'Required'}, {'Source_File': 'slides-bagging-random-forest_main.pdf', 'Source_Group': 'Bagging / Random Forest', 'Role': 'Main theory source', 'Key_Topics': 'Ensemble overview, bagging, Random Forest, decorrelation, randomized splits, feature importance, performance stability', 'Coverage_Action': 'Theory in chat, concise notebook reminders, practical RF experiments in Notebook 03', 'Status': 'Required'}, {'Source_File': 'slides-forests-bagging_part2.pdf', 'Source_Group': 'Bagging / Bootstrap', 'Role': 'Main detail source', 'Key_Topics': 'Bootstrap aggregation, bootstrap samples, in-bag data, out-of-bag data, aggregation rules', 'Coverage_Action': 'Bootstrap/OOB explanation and OOB score practical section in Notebook 03', 'Status': 'Required'}, {'Source_File': 'slides-forests-nutshell_part1.pdf', 'Source_Group': 'Random Forest overview', 'Role': 'Supporting theory source', 'Key_Topics': 'Learning and prediction with RF, aggregation rules, feature importance, ensemble size effect', 'Coverage_Action': 'Use for RF summary, feature importance, n_estimators stability', 'Status': 'Required'}, {'Source_File': '9-Cross-validation.pdf', 'Source_Group': 'Cross-validation', 'Role': 'Main support source', 'Key_Topics': 'Train/test splits, K-fold CV, model setting selection via CV, number of folds', 'Coverage_Action': 'Use in Notebook 04 and Notebook 05 for CV, OOF, model comparison, and stacking safety', 'Status': 'Required'}, {'Source_File': 'Gradient_boosting.pdf', 'Source_Group': 'Gradient Boosting / Stacking / Blending', 'Role': 'Main theory source', 'Key_Topics': 'Random Forest recap, Gradient Boosting, blending, stacking, meta-features, stacking pros/cons, recap of ensemble methods', 'Coverage_Action': 'Use for stacking/blending sections and boosting concept section in Notebook 06', 'Status': 'Required'}, {'Source_File': 'Gradient_boosting de.pdf / Gradient_boosting de_part1.pdf', 'Source_Group': 'German Gradient Boosting version', 'Role': 'Duplicate / cross-check source', 'Key_Topics': 'Same/similar content in German: GB theory, parallelization, recap of Bagging, RSM, RF, GB, Blending, Stacking', 'Coverage_Action': 'Use for cross-checking and German wording, not duplicate implementation', 'Status': 'Duplicate-support'}, {'Source_File': 'slides-boosting-gradient-boosting-concept_part2.pdf', 'Source_Group': 'Gradient Boosting concept', 'Role': 'Specific concept source', 'Key_Topics': 'Forward stagewise additive modelling, gradient boosting fitting process for regression', 'Coverage_Action': 'Detailed theory in chat, concise practical concept add-on in Notebook 06', 'Status': 'Required'}, {'Source_File': 'ensemble_learning_boosting.slides.html', 'Source_Group': 'Boosting implementation support', 'Role': 'Supporting source', 'Key_Topics': 'Gradient boosting implementation idea, loss minimization, trees added iteratively', 'Coverage_Action': 'Use as supporting reference for Notebook 06 mini-comparison', 'Status': 'Supporting'}, {'Source_File': 'TAG_09_Ensemble_Learning_Bagging_Stacking.slides.html', 'Source_Group': 'Day 9 practical slide/notebook export', 'Role': 'Practical reference', 'Key_Topics': 'Model definitions, cross_val_score, DecisionTree, RandomForest, KNN, XGBClassifier, stacking-related implementation style', 'Coverage_Action': 'Use as coding reference but improve structure, comments, charts, and business interpretation', 'Status': 'Supporting'}, {'Source_File': '09_Ensemble_Learning_Bagging_Stacking.py', 'Source_Group': 'Python script', 'Role': 'Practical reference', 'Key_Topics': 'Bagging, Random Forest, Stacking, Boosting overview and example code', 'Coverage_Action': 'Use as reference only; final notebooks will be cleaner and more project-ready', 'Status': 'Supporting'}, {'Source_File': 'ensemble(1).pdf', 'Source_Group': 'Image-only reference', 'Role': 'Visual/reference source', 'Key_Topics': 'Parsed text unavailable; use only if visual review is needed', 'Coverage_Action': 'Do not rely on this as primary source unless image content is inspected manually', 'Status': 'Reference-only'}, {'Source_File': 'week0_06_gradient_boosting.key', 'Source_Group': 'Keynote source', 'Role': 'Inaccessible original file', 'Key_Topics': 'Likely duplicated by accessible PDF/HTML versions', 'Coverage_Action': 'Mark as inaccessible; cover through PDF/HTML equivalents', 'Status': 'Inaccessible duplicate'}]
coverage_matrix_data = [('Ensemble learning overview', 'slides-bagging-random-forest_main.pdf, script', 'Chat detailed theory + NB1/NB2 short intro', 'NB2 baseline comparison', 'Explain why group prediction can improve stability', 'Planned'), ('Weak learners vs strong ensemble', 'MVD + ensemble slides', 'Chat detailed theory', 'NB2/NB3 model comparison', 'Connect weak individual models to stronger campaign prediction', 'Planned'), ('Bias-variance tradeoff', 'RF/ensemble slides + CV PDF', 'Chat detailed theory', 'NB2/NB3 train-test gap, CV results', 'Explain overfitting vs stable generalization', 'Planned'), ('Bagging', 'slides-forests-bagging_part2.pdf', 'Chat detailed theory + notebook reminder', 'NB3 BaggingClassifier / RF explanation', 'Show why repeated samples reduce unstable tree behavior', 'Planned'), ('Bootstrap samples', 'slides-forests-bagging_part2.pdf', 'Chat detailed theory', 'NB3 mini-demo / explanation', 'Rows/customers resampled with replacement', 'Planned'), ('In-bag and out-of-bag data', 'slides-forests-bagging_part2.pdf', 'Chat detailed theory', 'NB3 OOB score if supported', 'Built-in validation idea for RF', 'Planned'), ('Aggregation rules', 'slides-forests-nutshell_part1.pdf', 'Chat detailed theory', 'NB3 voting/probability explanation', 'Majority vote for classification', 'Planned'), ('Random Subspace Method', 'Gradient_boosting.pdf, RF slides', 'Chat detailed theory', 'NB3 max_features/RSM experiment', 'Different feature subsets create model diversity', 'Planned'), ('Random Forest', 'RF slides + MVD', 'Chat detailed theory', 'NB3 full model training', 'Main strong benchmark model', 'Planned'), ('Tree decorrelation', 'slides-bagging-random-forest_main.pdf', 'Chat detailed theory', 'NB3 RSM/max_features explanation', 'Trees should make different mistakes', 'Planned'), ('Decision Tree vs Random Forest', 'MVD Day 9', 'Short notebook reminder', 'NB3 required train/test comparison', 'Show single tree overfit vs forest stability', 'MVD-required'), ('Feature importance', 'RF slides + MVD', 'Chat explanation', 'NB3 side-by-side importance plots', 'Identify business drivers of subscription', 'MVD-required'), ('n_estimators stability', 'RF slides + MVD', 'Chat explanation', 'NB3 10–500 curve', 'Find point where more trees stop adding value', 'MVD-required'), ('Cross-validation', '9-Cross-validation.pdf', 'Chat detailed theory', 'NB4 CV comparison', 'More reliable model evaluation than one split', 'Planned'), ('K-fold CV', '9-Cross-validation.pdf', 'Chat detailed theory', 'NB4 cross_val_score cv=5', 'Every fold tested once', 'MVD-required'), ('Model setting selection via CV', '9-Cross-validation.pdf', 'Chat explanation', 'NB4 meta-model comparison', 'Use CV to judge model settings fairly', 'Planned'), ('StackingClassifier', 'MVD + stacking slides', 'Chat detailed theory', 'NB4 sklearn StackingClassifier', 'Different experts + final judge', 'MVD-required'), ('Base learner diversity', 'MVD + ensemble theory', 'Chat detailed theory', 'NB4 RF/LR/KNN/DT comparison', 'Different models capture different customer behavior', 'MVD-required'), ('Meta-features', 'Gradient_boosting.pdf stacking slides', 'Chat detailed theory', 'NB4/NB5 prediction feature tables', 'Base model predictions become new features', 'Planned'), ('Meta-model Logistic Regression', 'MVD Day 9', 'Chat explanation', 'NB4/NB5 required meta-model', 'Simple and stable final judge', 'MVD-required'), ('Meta-model Random Forest', 'MVD Day 9', 'Chat explanation', 'NB4 required swap', 'More flexible final judge, compare overfitting risk', 'MVD-required'), ('Manual OOF stacking', 'MVD + Gradient_boosting.pdf', 'Chat detailed theory', 'NB5 5-fold OOF implementation', 'Avoid data leakage in stacking', 'MVD-required'), ('Data leakage prevention', 'Stacking slides + CV PDF', 'Chat detailed theory', 'NB5 correct OOF generation', 'Meta-model must not learn from cheating predictions', 'Planned'), ('Blending', 'Gradient_boosting.pdf + MVD', 'Chat detailed theory', 'NB5 70/30 blend split', 'Simpler stacking but less training data', 'MVD-required'), ('OOF stacking vs blending', 'MVD Day 9', 'Chat explanation', 'NB5 accuracy/stability comparison', 'Compare robust vs simple ensemble method', 'MVD-required'), ('Three-layer stacking', 'MVD + stacking pros', 'Chat detailed theory', 'NB6 Level-0/1/2 implementation', 'Measure if extra complexity is worth it', 'MVD-required'), ('Gradient Boosting concept', 'Gradient_boosting.pdf, concept slides', 'Chat detailed theory', 'NB6 controlled mini-comparison', 'Sequential models fix previous mistakes', 'Planned'), ('Forward stagewise modelling', 'slides-boosting-gradient-boosting-concept_part2.pdf', 'Chat detailed theory', 'NB6 concise concept note', 'Build model step by step', 'Planned'), ('Loss function and gradient idea', 'Gradient_boosting files', 'Chat detailed theory', 'NB6 concise concept note', 'How boosting knows what to correct', 'Planned'), ('Parallelization discussion', 'Gradient_boosting de/pdf', 'Short explanation', 'NB6 final comparison note', 'RF trees parallel; GB sequential dependency', 'Planned'), ('Bagging vs Boosting vs Stacking', 'Gradient_boosting recap', 'Chat detailed theory', 'NB6/NB7 final comparison table', 'Choose method by business objective', 'Planned'), ('MVD final proof', 'MVD document', 'Not theory-heavy', 'NB7 checklist table', 'Prove every assignment item is complete', 'MVD-required'), ('Final business recommendation', 'Project layer', 'Not theory-heavy', 'NB7 final model recommendation', 'Campaign targeting recommendation', 'Planned')]
mvd_checklist_data = [('Beginner 1', 'Train DecisionTreeClassifier(max_depth=None) and RandomForestClassifier(n_estimators=100); compare train/test accuracy', 'NB3', 'Pending'), ('Beginner 2', 'Feature importance plots side by side; compare important features', 'NB3', 'Pending'), ('Beginner 3', 'Increase n_estimators 10 to 500 in steps of 10; plot test accuracy and stagnation point', 'NB3', 'Pending'), ('Intermediate 1', 'Create StackingClassifier with RandomForest, LogisticRegression, KNeighbors, DecisionTree; meta-model LogisticRegression; evaluate with cross_val_score', 'NB4', 'Pending'), ('Intermediate 2', 'Compare CV accuracy of all base learners vs StackingClassifier', 'NB4', 'Pending'), ('Intermediate 3', 'Swap meta-model for RandomForest; explain model diversity', 'NB4', 'Pending'), ('Expert 1', 'Manual 5-fold OOF stacking and meta-features', 'NB5', 'Pending'), ('Expert 2', 'Blending with 70/30 train/blend split; compare OOF stacking vs blending', 'NB5', 'Pending'), ('Expert 3', 'Three-layer stacking ensemble Level-0:4, Level-1:2, Level-2:1; judge effort vs gain', 'NB6', 'Pending')]
dataset_decision_data = [('Bank Marketing / Term Deposit', 'Binary classification', 5, 5, 5, 5, 4, 5, 'Best fit', 'Direct marketing campaign response prediction; strongest fit for BI + digital marketing profile'), ('Telco Customer Churn', 'Binary classification', 5, 4, 5, 5, 4, 4, 'Strong backup', 'Good business problem, but less directly connected to marketing campaign analytics'), ('Credit Risk / Loan Default', 'Binary classification', 5, 4, 5, 4, 3, 4, 'Possible backup', 'Strong business value, but may require more risk framing and careful metric discussion'), ('Wine Quality', 'Multi-class / classification adaptation', 2, 2, 3, 4, 5, 2, 'MVD recommended only', "Good teaching dataset but weak for Ruturaj's CV/business story"), ('Steel Industry Energy', 'Regression/classification adaptation', 3, 2, 3, 4, 3, 3, 'MVD recommended only', 'Useful industrial dataset, but not as clean for campaign conversion story')]
notebook_plan_data = [('01_Source_Audit_Coverage_Matrix_Dataset_Selection.ipynb', 'Source inventory, duplicate classification, coverage matrix, dataset selection, notebook architecture', 'Locks scope before coding'), ('02_Data_Preparation_Baseline_Models.ipynb', 'Load chosen dataset, clean columns, encode categorical features, split data, train simple baseline models', 'Creates reliable project foundation'), ('03_Bagging_RandomForest_RSM_OOB_FeatureImportance.ipynb', 'Decision Tree vs Random Forest, bootstrap/OOB, RSM/max_features, feature importance, n_estimators curve', 'Covers bagging and Random Forest practical core'), ('04_CrossValidation_StackingClassifier_ModelDiversity.ipynb', '5-fold CV, base learners, StackingClassifier, Logistic vs RF meta-model', 'Covers stacking and model diversity'), ('05_Manual_OOF_Stacking_and_Blending.ipynb', 'Manual OOF stacking, leakage-safe meta-features, 70/30 blending, OOF vs blending comparison', 'Covers expert stacking and blending'), ('06_ThreeLayer_Stacking_and_GradientBoosting_Concepts.ipynb', 'Three-layer stacking, extra-effort evaluation, gradient boosting concept and controlled comparison', 'Covers advanced ensemble layer and uploaded boosting material'), ('07_MVD_Proof_Final_Business_Recommendation.ipynb', 'MVD proof checklist, final model comparison, business recommendation, limitations, next steps', 'Submission-ready proof and conclusion')]

source_inventory = pd.DataFrame(source_inventory_data)
coverage_matrix = pd.DataFrame(
    coverage_matrix_data,
    columns=["Topic", "Source", "Theory_Coverage", "Practical_Coverage", "Business_Interpretation", "Status"]
)
mvd_checklist = pd.DataFrame(
    mvd_checklist_data,
    columns=["MVD_Level_Item", "Requirement", "Planned_Notebook", "Status"]
)
dataset_decision = pd.DataFrame(
    dataset_decision_data,
    columns=[
        "Dataset", "Task_Type", "Business_Relevance", "Profile_Fit", "Feature_Importance_Value",
        "Works_For_Ensembles", "Runtime_Friendliness", "Final_Story_Strength", "Decision", "Reason"
    ]
)
notebook_plan = pd.DataFrame(
    notebook_plan_data,
    columns=["Notebook", "Main_Content", "Purpose"]
)

# Save planning artifacts so later notebooks and final documentation can reuse the same scope.
source_inventory.to_csv(reports_dir / "day9_source_inventory.csv", index=False)
coverage_matrix.to_csv(reports_dir / "day9_coverage_matrix.csv", index=False)
mvd_checklist.to_csv(reports_dir / "day9_mvd_checklist.csv", index=False)
dataset_decision.to_csv(reports_dir / "day9_dataset_decision.csv", index=False)
notebook_plan.to_csv(reports_dir / "day9_notebook_plan.csv", index=False)

print("Planning files created in reports/:")
for file_path in sorted(reports_dir.glob("day9_*.csv")):
    print(f"- {file_path}")
# Out:
# Planning files created in reports/:
# - reports/day9_coverage_matrix.csv
# - reports/day9_dataset_decision.csv
# - reports/day9_mvd_checklist.csv
# - reports/day9_notebook_plan.csv
# - reports/day9_source_inventory.csv

# %% [markdown]
# <div style="
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Arial, sans-serif;
#   line-height: 1.55;
#   color: var(--vscode-editor-foreground);
# ">
#
# <h3 style="margin-bottom:6px;">Source inventory</h3>
# <p>
# This table lists every Day 9 source group and how it will be used. Duplicate sources are not ignored; they are used for cross-checking without repeating the same implementation twice.
# </p>
#
# </div>

# %%
# Source inventory table
source_inventory
# Out:
#                                           Source_File  \
# 0         MVD_ML_Tasks_English_educx_CI-merged(2).pdf
# 1               slides-bagging-random-forest_main.pdf
# 2                    slides-forests-bagging_part2.pdf
# 3                   slides-forests-nutshell_part1.pdf
# 4                              9-Cross-validation.pdf
# 5                               Gradient_boosting.pdf
# 6   Gradient_boosting de.pdf / Gradient_boosting d...
# 7   slides-boosting-gradient-boosting-concept_part...
# 8              ensemble_learning_boosting.slides.html
# 9   TAG_09_Ensemble_Learning_Bagging_Stacking.slid...
# 10           09_Ensemble_Learning_Bagging_Stacking.py
# 11                                    ensemble(1).pdf
# 12                     week0_06_gradient_boosting.key
#
#                                Source_Group                            Role  \
# 0                            MVD assignment         Minimum proof checklist
# ...

# %% [markdown]
# <div style="
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Arial, sans-serif;
#   line-height: 1.55;
#   color: var(--vscode-editor-foreground);
# ">
#
# <h3 style="margin-bottom:6px;">Coverage matrix</h3>
# <p>
# This is the most important table in the notebook. A topic is only considered complete when it is mapped to theory, practical implementation, business interpretation, and final proof/documentation where needed.
# </p>
#
# <div style="border-left:4px solid #22c55e; padding:10px 14px; margin:12px 0; background:var(--vscode-editorWidget-background); border-radius:6px;">
# <strong>Project rule:</strong><br>
# If a topic appears in the uploaded lecture materials, it must be covered practically, theoretically, or explicitly marked as duplicate/reference-only with a reason.
# </div>
#
# </div>

# %%
# Full Day 9 coverage matrix
coverage_matrix
# Out:
#                                Topic  \
# 0         Ensemble learning overview
# 1   Weak learners vs strong ensemble
# 2             Bias-variance tradeoff
# 3                            Bagging
# 4                  Bootstrap samples
# 5         In-bag and out-of-bag data
# 6                  Aggregation rules
# 7             Random Subspace Method
# 8                      Random Forest
# 9                 Tree decorrelation
# 10    Decision Tree vs Random Forest
# 11                Feature importance
# 12            n_estimators stability
# 13                  Cross-validation
# 14                         K-fold CV
# 15    Model setting selection via CV
# 16                StackingClassifier
# 17            Base learner diversity
# 18                     Meta-features
# 19    Meta-model Logistic Regression
# 20          Meta-model Random Forest
# 21               Manual OOF stacking
# 22           Data leakage prevention
# 23                          Blending
# ...

# %% [markdown]
# <div style="
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Arial, sans-serif;
#   line-height: 1.55;
#   color: var(--vscode-editor-foreground);
# ">
#
# <h3 style="margin-bottom:6px;">MVD assignment proof checklist</h3>
# <p>
# The MVD checklist is tracked separately because it is the formal assignment requirement. It is a proof checklist, not the full project boundary.
# </p>
#
# </div>

# %%
# MVD proof checklist
mvd_checklist
# Out:
#    MVD_Level_Item                                        Requirement  \
# 0      Beginner 1  Train DecisionTreeClassifier(max_depth=None) a...
# 1      Beginner 2  Feature importance plots side by side; compare...
# 2      Beginner 3  Increase n_estimators 10 to 500 in steps of 10...
# 3  Intermediate 1  Create StackingClassifier with RandomForest, L...
# 4  Intermediate 2  Compare CV accuracy of all base learners vs St...
# 5  Intermediate 3  Swap meta-model for RandomForest; explain mode...
# 6        Expert 1       Manual 5-fold OOF stacking and meta-features
# 7        Expert 2  Blending with 70/30 train/blend split; compare...
# 8        Expert 3  Three-layer stacking ensemble Level-0:4, Level...
#
#   Planned_Notebook   Status
# 0              NB3  Pending
# 1              NB3  Pending
# 2              NB3  Pending
# 3              NB4  Pending
# 4              NB4  Pending
# 5              NB4  Pending
# 6              NB5  Pending
# 7              NB5  Pending
# ...

# %% [markdown]
# <div style="
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Arial, sans-serif;
#   line-height: 1.55;
#   color: var(--vscode-editor-foreground);
# ">
#
# <h3 style="margin-bottom:6px;">Dataset selection</h3>
# <p>
# The recommended project dataset is <strong>Bank Marketing / Term Deposit Subscription Prediction</strong> because it is a real campaign-response classification problem and fits Ruturaj's Data Analyst / BI / digital marketing profile.
# </p>
#
# <div style="border-left:4px solid #38bdf8; padding:10px 14px; margin:12px 0; background:var(--vscode-editorWidget-background); border-radius:6px;">
# <strong>Important points for understanding</strong><br>
# <ul style="margin:6px 0 0 18px; padding:0;">
# <li>We need a classification dataset because the Day 9 MVD uses classifier models.</li>
# <li>We need business-friendly features so feature importance has real meaning.</li>
# <li>We need enough rows for cross-validation, OOF stacking, and blending.</li>
# <li>We avoid Wine Quality as the main dataset because it is weaker for BI/campaign analytics storytelling.</li>
# </ul>
# </div>
#
# </div>

# %%
# Dataset decision scoring table
dataset_decision
# Out:
#                          Dataset                                Task_Type  \
# 0  Bank Marketing / Term Deposit                    Binary classification
# 1           Telco Customer Churn                    Binary classification
# 2     Credit Risk / Loan Default                    Binary classification
# 3                   Wine Quality  Multi-class / classification adaptation
# 4          Steel Industry Energy     Regression/classification adaptation
#
#    Business_Relevance  Profile_Fit  Feature_Importance_Value  \
# 0                   5            5                         5
# 1                   5            4                         5
# 2                   5            4                         5
# 3                   2            2                         3
# 4                   3            2                         3
#
#    Works_For_Ensembles  Runtime_Friendliness  Final_Story_Strength  \
# 0                    5                     4                     5
# ...

# %% [markdown]
# <div style="
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Arial, sans-serif;
#   line-height: 1.55;
#   color: var(--vscode-editor-foreground);
# ">
#
# <h3 style="margin-bottom:6px;">Final Day 9 notebook architecture</h3>
# <p>
# The project is split into seven notebooks so that each topic remains focused and readable.
# </p>
#
# </div>

# %%
# Planned notebook architecture
notebook_plan
# Out:
#                                             Notebook  \
# 0  01_Source_Audit_Coverage_Matrix_Dataset_Select...
# 1          02_Data_Preparation_Baseline_Models.ipynb
# 2  03_Bagging_RandomForest_RSM_OOB_FeatureImporta...
# 3  04_CrossValidation_StackingClassifier_ModelDiv...
# 4          05_Manual_OOF_Stacking_and_Blending.ipynb
# 5  06_ThreeLayer_Stacking_and_GradientBoosting_Co...
# 6   07_MVD_Proof_Final_Business_Recommendation.ipynb
#
#                                         Main_Content  \
# 0  Source inventory, duplicate classification, co...
# 1  Load chosen dataset, clean columns, encode cat...
# 2  Decision Tree vs Random Forest, bootstrap/OOB,...
# 3  5-fold CV, base learners, StackingClassifier, ...
# 4  Manual OOF stacking, leakage-safe meta-feature...
# 5  Three-layer stacking, extra-effort evaluation,...
# 6  MVD proof checklist, final model comparison, b...
#
#                                              Purpose
# 0                          Locks scope before coding
# ...

# %% [markdown]
# <div style="
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Arial, sans-serif;
#   line-height: 1.55;
#   color: var(--vscode-editor-foreground);
# ">
#
# <h3 style="margin-bottom:6px;">Quality standard for all Day 9 notebooks</h3>
#
# <table style="border-collapse:collapse; width:100%; font-size:14px;">
# <thead>
# <tr>
# <th style="text-align:left; border-bottom:1px solid #888; padding:6px;">Standard</th>
# <th style="text-align:left; border-bottom:1px solid #888; padding:6px;">How it will be applied</th>
# </tr>
# </thead>
# <tbody>
# <tr><td style="padding:6px;">Theory</td><td style="padding:6px;">Detailed theory in chat first; notebook includes concise reminders only.</td></tr>
# <tr><td style="padding:6px;">Markdown</td><td style="padding:6px;">Clean HTML Markdown, readable spacing, no ugly large headers or walls of text.</td></tr>
# <tr><td style="padding:6px;">Code</td><td style="padding:6px;">Small cells, clear comments, variable/source/output flow explained where useful.</td></tr>
# <tr><td style="padding:6px;">Charts</td><td style="padding:6px;">Professional BI-ready visuals with titles, labels, annotations, and interpretation.</td></tr>
# <tr><td style="padding:6px;">Interpretation</td><td style="padding:6px;">Every major output gets technical meaning and business meaning.</td></tr>
# <tr><td style="padding:6px;">Paths</td><td style="padding:6px;">Only relative folders such as <code>data/</code>, <code>reports/</code>, and <code>outputs/</code>.</td></tr>
# </tbody>
# </table>
#
# </div>

# %% [markdown]
# <div style="
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Arial, sans-serif;
#   line-height: 1.55;
#   color: var(--vscode-editor-foreground);
# ">
#
# <h3 style="margin-bottom:6px;">Conclusion — Notebook 01</h3>
#
# <div style="border-left:4px solid #22c55e; padding:10px 14px; margin:12px 0; background:var(--vscode-editorWidget-background); border-radius:6px;">
# <strong>Scope is locked.</strong><br>
# Day 9 will cover the full uploaded ensemble-learning material, not only the MVD checklist. The selected project direction is Bank Marketing / Term Deposit Subscription Prediction because it gives the strongest business story for customer analytics and campaign-response modelling.
# </div>
#
# <p><strong>Next notebook:</strong> <code>02_Data_Preparation_Baseline_Models.ipynb</code></p>
# <p>
# Next we will load the chosen dataset, inspect the target, clean/encode features, create train/test splits, and build baseline models before moving into Random Forest and stacking.
# </p>
#
# </div>
